# %%
#@title Colab VSCode
#@markdown Run this cell to access VS Code on your browser powered by Google Colab.

#@markdown *This service uses VS Code Tunnels to generate a URL for VS Code.*

# Install colabconnect
# !pip install --quiet colabconnect &> /dev/null

from colabcode import ColabCode

colabconnect()
